# %%
# import libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# read data

member = pd.read_csv('/Users/maggietang/Downloads/Member Details.csv')
visit = pd.read_csv('/Users/maggietang/Downloads/Visit Dataset.csv')
outcome = pd.read_csv('/Users/maggietang/Downloads/Program Outcomes.csv')
interaction = pd.read_csv('/Users/maggietang/Downloads/Interactions Dataset.csv')

# %%
# datasets shape

member.shape, visit.shape, outcome.shape, interaction.shape
# Out:
# ((3218, 41), (24882, 57), (3218, 12), (90645, 6))

# %% [raw]
# check missing values
# Many missing values are expected because healthcare datasets often contain optional fields, not errors,We keep them without imputation, because imputing sensitive medical data would distort outcomes

# %%
member.isna().sum()
#visit.isna().sum(), outcome.isna().sum(), interaction.isna().sum()
# Out:
# patient_id                                     0
# estimated_delivery_date                     1504
# gravida                                     1068
# parity                                      1349
# marital_status                              1549
# date_of_birth                                  0
# zip_3                                          0
# zip_income_median                             26
# zip_income_mean                               23
# education_level                             2428
# is_nulliparous                                 0
# has_pcp_at_enrollment                          0
# history_of_opioids_at_enrollment               0
# history_of_bh_at_enrollment                    0
# asthma_at_enrollment                           0
# diabetes_at_enrollment                         0
# history_of_gd_at_enrollment                    0
# hypertension_at_enrollment                     0
# history_of_preterm_at_enrollment               0
# active_nicotine_use_at_enrollment              0
# has_financial_barrier_at_enrollment            0
# has_transportation_barrier_at_enrollment       0
# has_safety_barrier_at_enrollment               0
# has_food_security_barrier_at_enrollment        0
# has_housing_barrier_at_enrollment              0
# delivery_date                               1935
# gestational_age_at_delivery                 2129
# gestational_age_weeks_at_registration       1390
# chronological_age_weeks_at_registration     3026
# race_arab                                     19
# race_black_aa                                 19
# race_egyptian                                 19
# race_others                                   19
# race_white_caucasian                          19
# ethnicity_hispanic_latino                     21
# ethnicity_patient_declined                    21
# preferred_language_declined                   10
# preferred_language_english                    10
# program_start_date                             0
# program_end_date                            2648
# program_closure_reason                         0
# dtype: int64

# %% [raw]
# check summary stats for each table
# gives a quick statistical summary of all numeric columns. It helps me understand the distribution, detect outliers, spot data quality issues, and get a first sense of patterns

# %%
member.describe()
# visit.describe(), outcome.describe(), interaction.describe()
# Out:
#            gravida       parity  marital_status        zip_3  \
# count  2150.000000  1869.000000     1669.000000  3218.000000
# mean      2.849302     1.739968        0.272618   187.325047
# std       2.120956     1.488288        0.445440    20.221604
# min       0.000000     0.000000        0.000000    70.000000
# 25%       1.000000     1.000000        0.000000   191.000000
# 50%       2.000000     1.000000        0.000000   191.000000
# 75%       4.000000     2.000000        1.000000   191.000000
# max      23.000000    14.000000        1.000000   198.000000
#
#        zip_income_median  zip_income_mean  education_level  \
# count        3192.000000      3195.000000       790.000000
# mean        43685.113409     60503.567449         2.487342
# std         17802.051496     22102.666398         0.746240
# min         18285.000000     29630.000000         0.000000
# 25%         29308.000000     45325.000000         2.000000
# 50%         38087.000000     53134.000000         3.000000
# 75%         54178.000000     68789.000000         3.000000
# max        141426.000000    328825.000000         3.000000
#
#        has_pcp_at_enrollment  history_of_opioids_at_enrollment  \
# count            3218.000000                       3218.000000
# mean                0.964264                          0.378496
# std                 0.185661                          0.485088
# min                 0.000000                          0.000000
# 25%                 1.000000                          0.000000
# 50%                 1.000000                          0.000000
# 75%                 1.000000                          1.000000
# max                 1.000000                          1.000000
#
#        asthma_at_enrollment  ...  chronological_age_weeks_at_registration  \
# count           3218.000000  ...                               192.000000
# mean               0.501243  ...                                 7.109375
# std                0.500076  ...                                11.611671
# min                0.000000  ...                                 0.000000
# 25%                0.000000  ...                                 1.000000
# 50%                1.000000  ...                                 3.000000
# 75%                1.000000  ...                                 8.000000
# max                1.000000  ...                                56.000000
#
#          race_arab  race_black_aa  race_egyptian  race_others  \
# count  3199.000000    3199.000000    3199.000000  3199.000000
# mean      0.000313       0.497968       0.000313     0.266021
# std       0.017680       0.500074       0.017680     0.441944
# min       0.000000       0.000000       0.000000     0.000000
# 25%       0.000000       0.000000       0.000000     0.000000
# 50%       0.000000       0.000000       0.000000     0.000000
# 75%       0.000000       1.000000       0.000000     1.000000
# max       1.000000       1.000000       1.000000     1.000000
#
#        race_white_caucasian  ethnicity_hispanic_latino  \
# count           3199.000000                3197.000000
# mean               0.235386                   0.098843
# std                0.424306                   0.298497
# min                0.000000                   0.000000
# 25%                0.000000                   0.000000
# 50%                0.000000                   0.000000
# 75%                0.000000                   0.000000
# max                1.000000                   1.000000
#
#        ethnicity_patient_declined  preferred_language_declined  \
# count                 3197.000000                  3208.000000
# mean                     0.422584                     0.004676
# std                      0.494048                     0.068230
# min                      0.000000                     0.000000
# 25%                      0.000000                     0.000000
# 50%                      0.000000                     0.000000
# 75%                      1.000000                     0.000000
# max                      1.000000                     1.000000
#
#        preferred_language_english
# count                 3208.000000
# mean                     0.977556
# std                      0.148145
# min                      0.000000
# 25%                      1.000000
# 50%                      1.000000
# 75%                      1.000000
# max                      1.000000
#
# [8 rows x 31 columns]

# %% [raw]
# Q1: Analyze Engagement and Retention

# %%
# Count total interactions per member

interaction['total_interactions'] = (
    interaction[['interaction_type_EMAIL',
                 'interaction_type_SMS',
                 'interaction_type_VISIT',
                 'interaction_type_VOICE_CALL']].sum(axis=1)
)

member_interactions = (
    interaction.groupby('patient_id')['total_interactions']
               .sum()
               .reset_index()
               .rename(columns={'total_interactions': 'engagement_score'})
)

# %%
# Count total visits per member

visit['total_visits'] = (
    visit[['visit_status_completed',
           'visit_status_canceled',
           'visit_status_no_show',
           'visit_status_scheduled']].sum(axis=1)
)

member_visits = (
    visit.groupby('patient_id')['total_visits']
         .sum()
         .reset_index()
)

# %%
# Build engagement dataset and fill missing metrics

member['program_start_date'] = pd.to_datetime(member['program_start_date'])
member['program_end_date'] = pd.to_datetime(member['program_end_date'])

engagement = (
    member[['patient_id', 'program_start_date', 'program_end_date']]
    .merge(member_interactions, on='patient_id', how='left')
    .merge(member_visits, on='patient_id', how='left')
)

engagement.fillna({'engagement_score': 0, 'total_visits': 0}, inplace=True)

# %%
engagement.isna().sum()

# need to fill missing values in program_end_date
# Out:
# patient_id               0
# program_start_date       0
# program_end_date      2648
# engagement_score         0
# total_visits             0
# dtype: int64

# %%
# Calculate median time in program for members with valid end dates

valid_durations = (
    engagement.dropna(subset=['program_end_date'])
    .assign(duration=lambda df: (df['program_end_date'] - df['program_start_date']).dt.days)
)

median_duration = valid_durations['duration'].median()

# Fill missing program_end_date with start_date + median program duration
engagement['program_end_date'] = engagement['program_end_date'].fillna(
    engagement['program_start_date'] + pd.to_timedelta(median_duration, unit='D')
)

# %% [raw]
# Because program_end_date represents program completion (not biological pregnancy length), imputed missing values using the median program duration from members with complete data. This avoids introducing assumptions and preserves the dataset’s natural patterns

# %%
# Convert program dates to datetime and calculate each member's retention duration in days.

#engagement['program_start_date'] = pd.to_datetime(engagement['program_start_date'])
#engagement['program_end_date'] = pd.to_datetime(engagement['program_end_date'])

engagement['retention_days'] = (
    engagement['program_end_date'] - engagement['program_start_date']
).dt.days

# %%
# Compute key engagement metrics including interactions, visits, and average retention.

eng_summary = {
    'Avg Interactions per Member': float(engagement['engagement_score'].mean()),
    'Median Interactions': float(engagement['engagement_score'].median()),
    'Avg Visits per Member': float(engagement['total_visits'].mean()),
    'Avg Retention Days': float(engagement['retention_days'].mean())
}

eng_summary
# Out:
# {'Avg Interactions per Member': 32.75699192044748,
#  'Median Interactions': 17.0,
#  'Avg Visits per Member': 9.213486637663145,
#  'Avg Retention Days': 211.5074580484773}

# %%
engagement.describe()
# Out:
#                   program_start_date               program_end_date  \
# count                           3218                           3218
# mean   2023-05-08 21:56:02.834058496  2023-12-06 19:59:15.251709440
# min              2021-10-20 00:00:00            2022-05-09 12:00:00
# 25%              2022-04-07 06:00:00            2022-11-01 12:00:00
# 50%              2023-04-18 00:00:00            2023-12-05 00:00:00
# 75%              2024-04-24 00:00:00            2024-12-31 00:00:00
# max              2025-04-23 00:00:00            2025-11-10 12:00:00
# std                              NaN                            NaN
#
#        engagement_score  total_visits  retention_days
# count       3218.000000   3218.000000     3218.000000
# mean          32.756992      9.213487      211.507458
# min            0.000000      0.000000       -5.000000
# 25%            7.000000      2.000000      201.000000
# 50%           17.000000      5.000000      201.000000
# 75%           48.750000     13.000000      201.000000
# max          279.000000     86.000000     1248.000000
# std           37.369713     10.717533      116.971618

# %%
# best cutoff based on above stats, adjust based on business needs

bins = [0, 7, 17, 49, 1000]
labels = ['Low', 'Moderate', 'High', 'Very High']

engagement['engagement_level'] = pd.cut(
    engagement['engagement_score'],
    bins=bins,
    labels=labels,
    include_lowest=True
)

engagement['engagement_level'].value_counts()
# Out:
# engagement_level
# Low          916
# High         815
# Very High    789
# Moderate     698
# Name: count, dtype: int64

# %% [raw]
# Engagement shows a bimodal pattern: many members have minimal activity, but those who do engage tend to engage heavily. This suggests improving early touchpoints and onboarding may help shift members from Low to Moderate/High categories.

# %%
engagement[['engagement_score', 'retention_days']].corr()
# Out:
#                   engagement_score  retention_days
# engagement_score          1.000000        0.233399
# retention_days            0.233399        1.000000

# %% [raw]
# Members who stay longer in the program are meaningfully more engaged. Improving retention has a direct, measurable impact on engagement
